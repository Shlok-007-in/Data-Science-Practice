# %%
#1. Code Cell 

#2. Markdown Cell 

#3. What is Compiler 

#4. What is Interpreter 

#5. What is Kernel.

# %%
# in Jupyter Notebook we can write our code in a cell. 
# By default cell is always in Code Mode. 
# Code mode is where cell expects the users to write the syntax and it will execute the code. 
# cell is a block where we write our code. 
# we can write comments alos by mentioning # before the comment

# if we dont mention the # symbol the cell state acts as a Code state and tries to execute the command.

# %%
# we can write comments als0 by mentioning  before the comment

# %% [markdown]
# Once the cell mode is changed from code to markdown that cell loses its code mode properties and it act a markdown where in we can add header and take plain text etc.

# %% [markdown]
# # Python

# %% [markdown]
# ## Python

# %% [markdown]
# ### Python

# %% [markdown]
# #### Python

# %% [markdown]
# ##### Python

# %% [markdown]
# ###### python

# %% [markdown]
# ####### python
